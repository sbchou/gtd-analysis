# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas
import inspect
from datetime import datetime
import seaborn as sns
import glob
from os.path import basename
sns.set_context('poster')
import re
import csv

# %%
pandas.options.display.max_rows = 4000
pandas.options.display.max_colwidth = 4000

# %% [markdown]
# ## Load files

# %%
df = pandas.read_excel('../data/globalterrorismdb_0616dist.xlsx')

# %%
df_15_16 = pandas.read_excel('../data/Global Terrorism Database 2015-2016 Preliminary Data EMBARGOED.xlsx')

# %%
# is the newest 2015 data same as last?
print(df[df.iyear==2015].eventid.count())
print(df_15_16[df_15_16.iyear==2015].eventid.count())
# Out:
# 14806
# 14843

# %%
#let's use the latest 2015
df = pandas.concat([df[df.iyear < 2015], df_15_16])

# %% [markdown]
# Check basic stats

# %%
print df.eventid.count()
print df.iyear.unique()

# %%
df.groupby('iyear').nkill.sum()[36:].sort_values(ascending=False)
# Out:
# iyear
# 2014    43550
# 2015    38471
# 2016    34623
# 2013    22226
# 2012    15432
# 2007    12836
# 2009     9271
# 2008     9093
# 2011     8198
# 2010     7720
# Name: nkill, dtype: float64

# %% [markdown]
# ## Analyze looking at long tails

# %%
df[(df.iyear > 2006)&(df.nkill > 100)].groupby(["gname"]).eventid.count().sort_values(ascending=False)
# Out:
# gname
# Islamic State of Iraq and the Levant (ISIL)                   24
# Boko Haram                                                    20
# Unknown                                                        6
# Al-Shabaab                                                     4
# Donetsk People's Republic                                      3
# Taliban                                                        3
# Al-Qaida in Iraq                                               3
# Tehrik-i-Taliban Pakistan (TTP)                                3
# Sudan People's Liberation Movement in Opposition (SPLM-IO)     2
# Al-Qaida in the Arabian Peninsula (AQAP)                       2
# Ansar al-Din Front                                             1
# Communist Party of India - Maoist (CPI-Maoist)                 1
# David Yau Yau Militia                                          1
# Islamic State of Iraq (ISI)                                    1
# ...

# %% [markdown]
# ### Deadliest attacks by ISIL

# %%
df[(df.iyear > 2006)&(df.gname=='Islamic State of Iraq and the Levant (ISIL)')].sort_values('nkill', ascending=False)[['iyear','imonth','iday','gname','nkill','attacktype1_txt','city','country_txt']][:20]
# Out:
#         iyear  imonth  iday                                        gname  \
# 133286   2014       6    12  Islamic State of Iraq and the Levant (ISIL)
# 132993   2014       6    10  Islamic State of Iraq and the Levant (ISIL)
# 136503   2014       8    19  Islamic State of Iraq and the Levant (ISIL)
# 136045   2014       8     3  Islamic State of Iraq and the Levant (ISIL)
# 27719    2016      12    10  Islamic State of Iraq and the Levant (ISIL)
# 21920    2016       7     3  Islamic State of Iraq and the Levant (ISIL)
# 134879   2014       7    17  Islamic State of Iraq and the Levant (ISIL)
# 4304     2015       4     9  Islamic State of Iraq and the Levant (ISIL)
# 16286    2016       2     7  Islamic State of Iraq and the Levant (ISIL)
# 25927    2016      10    21  Islamic State of Iraq and the Levant (ISIL)
# 6055     2015       5    21  Islamic State of Iraq and the Levant (ISIL)
# 19054    2016       4    21  Islamic State of Iraq and the Levant (ISIL)
# ...

# %% [markdown]
# ### Deadliest attacks in last 10 years

# %%
df[(df.iyear > 2006)].sort_values('nkill', ascending=False)[['iyear','imonth','iday','gname','nkill','attacktype1_txt']][:20].to_csv("../data/cover-story/top-20-deadliest-06-16.csv")

# %%
df[(df.iyear > 2006)].sort_values('nkill', ascending=False)[['iyear','imonth','iday','gname','nkill','attacktype1_txt']][:20]
# Out:
#         iyear  imonth  iday  \
# 133286   2014       6    12
# 132993   2014       6    10
# 136503   2014       8    19
# 136045   2014       8     3
# 27719    2016      12    10
# 90276    2009       1    17
# 21920    2016       7     3
# 131118   2014       5     5
# 134879   2014       7    17
# 4304     2015       4     9
# 16286    2016       2     7
# 134889   2014       7    17
# 130195   2014       4    15
# 25927    2016      10    21
# 23750    2016       8    19
# 6055     2015       5    21
# 83902    2007       8    14
# 83910    2007       8    14
# 19054    2016       4    21
# 11240    2015       9    28
#
#                                                     gname   nkill  \
# 133286        Islamic State of Iraq and the Levant (ISIL)  1500.0
# 132993        Islamic State of Iraq and the Levant (ISIL)   670.0
# 136503        Islamic State of Iraq and the Levant (ISIL)   517.0
# 136045        Islamic State of Iraq and the Levant (ISIL)   500.0
# ...

# %% [markdown]
# ### Deadliest attacks by genre (last 10 years)

# %% [markdown]
# #### Cumulatively deadliest type of attack, past 10 years

# %%
df[(df.iyear > 2006)].groupby('attacktype1_txt').eventid.count().sort_values(ascending=False).plot(kind='bar')
plt.title("Most freq type of attack  since 2006")

# %%
df[(df.iyear > 2006)].groupby('attacktype1_txt').nkill.sum().sort_values(ascending=False).plot(kind='bar')
plt.title("Deadliest type of attack: cumulative deaths since 2006")

# %%
df[(df.iyear > 2006)].groupby('attacktype1_txt').nkill.sum().sort_values(ascending=False)
# Out:
# attacktype1_txt
# Bombing/Explosion                      96997.60
# Armed Assault                          61552.97
# Hostage Taking (Kidnapping)            18026.25
# Unknown                                14877.84
# Assassination                           6412.33
# Hostage Taking (Barricade Incident)     1747.00
# Facility/Infrastructure Attack          1522.01
# Hijacking                                144.00
# Unarmed Assault                          140.00
# Name: nkill, dtype: float64

# %% [markdown]
# #### Kind of attack with highest number of deaths per attack

# %%
df[(df.iyear > 2006)].groupby('attacktype1_txt').nkill.mean().sort_values(ascending=False)
# Out:
# attacktype1_txt
# Hostage Taking (Barricade Incident)    7.434043
# Unknown                                4.832036
# Hostage Taking (Kidnapping)            3.902630
# Armed Assault                          3.026798
# Bombing/Explosion                      2.080377
# Assassination                          1.226301
# Hijacking                              0.774194
# Unarmed Assault                        0.382514
# Facility/Infrastructure Attack         0.359898
# Name: nkill, dtype: float64

# %%
df[(df.iyear > 2006)].groupby('attacktype1_txt').nkill.mean().sort_values(ascending=False).plot(kind='bar')
plt.ylabel("Average number of deaths")
plt.title('Deadliest methods, last 10 years')

# %%
df[(df.iyear > 2006)].sort_values('nkill', ascending=False)[['iyear','imonth','iday','gname','nkill','attacktype1_txt','claimed','city','country_txt']][:10]
# Out:
#         iyear  imonth  iday                                        gname  \
# 133286   2014       6    12  Islamic State of Iraq and the Levant (ISIL)
# 132993   2014       6    10  Islamic State of Iraq and the Levant (ISIL)
# 136503   2014       8    19  Islamic State of Iraq and the Levant (ISIL)
# 136045   2014       8     3  Islamic State of Iraq and the Levant (ISIL)
# 27719    2016      12    10  Islamic State of Iraq and the Levant (ISIL)
# 90276    2009       1    17                 Lord's Resistance Army (LRA)
# 21920    2016       7     3  Islamic State of Iraq and the Levant (ISIL)
# 131118   2014       5     5                                   Boko Haram
# 134879   2014       7    17  Islamic State of Iraq and the Levant (ISIL)
# 4304     2015       4     9  Islamic State of Iraq and the Levant (ISIL)
#
#          nkill                 attacktype1_txt  claimed              city  \
# 133286  1500.0     Hostage Taking (Kidnapping)      1.0            Tikrit
# ...

# %%
df[(df.iyear > 2006)].groupby('attacktype1_txt').nkill.sum().sort_values(ascending=False)
# Out:
# attacktype1_txt
# Bombing/Explosion                      96997.60
# Armed Assault                          61552.97
# Hostage Taking (Kidnapping)            18026.25
# Unknown                                14877.84
# Assassination                           6412.33
# Hostage Taking (Barricade Incident)     1747.00
# Facility/Infrastructure Attack          1522.01
# Hijacking                                144.00
# Unarmed Assault                          140.00
# Name: nkill, dtype: float64

# %% [markdown]
# ### Deadliest group (last 10 years)

# %%
df[(df.iyear > 2006)].groupby('gname').nkill.sum().sort_values(ascending=False)[:10]
# Out:
# gname
# Unknown                                        60655.67
# Islamic State of Iraq and the Levant (ISIL)    30815.33
# Taliban                                        23289.00
# Boko Haram                                     18530.00
# Al-Shabaab                                      7339.00
# Tehrik-i-Taliban Pakistan (TTP)                 5685.00
# Al-Qaida in Iraq                                3382.80
# Al-Qaida in the Arabian Peninsula (AQAP)        3353.00
# Al-Nusrah Front                                 2954.00
# Fulani Militants                                2727.00
# Name: nkill, dtype: float64

# %% [markdown]
# ### Deadliest group 2016

# %%
df[(df.iyear > 2015)].groupby('gname').nkill.sum().sort_values(ascending=False)[:10]
# Out:
# gname
# Islamic State of Iraq and the Levant (ISIL)                   11570.0
# Unknown                                                        5666.0
# Taliban                                                        5025.0
# Al-Shabaab                                                     1535.0
# Boko Haram                                                     1437.0
# Huthi Extremists                                                856.0
# Fulani Militants                                                819.0
# Khorasan Chapter of the Islamic State                           664.0
# Kurdistan Workers' Party (PKK)                                  583.0
# Sudan People's Liberation Movement in Opposition (SPLM-IO)      404.0
# Name: nkill, dtype: float64

# %% [markdown]
# ### Deadliest group on average (too few rows)

# %%
df[(df.iyear > 2006)].groupby('gname').nkill.mean().sort_values(ascending=False)[:10]
# Out:
# gname
# Ansar al-Din Front                                                          103.000000
# Agwelek Forces                                                               56.000000
# Kata'ib Hezbollah                                                            49.000000
# Jaish al-Sunnah                                                              43.000000
# Popular Front for the Renaissance of the Central African Republic (FPRC)     42.500000
# Islamic Movement for the Liberation of Raja                                  42.000000
# Liwa al-Haqq                                                                 40.000000
# Tehrik-e-Taliban Islami (TTI)                                                40.000000
# David Yau Yau Militia                                                        36.333333
# Kokang                                                                       34.000000
# Name: nkill, dtype: float64

# %%
df[(df.iyear > 2006)&(df.gname=='Ansar al-Din Front')].sort_values('nkill').nkill
# Out:
# 2417      6.0
# 4974    200.0
# Name: nkill, dtype: float64

# %% [markdown]
# ### Are the majority of deaths caused by outliers?

# %% [markdown]
# #### The distribution of deaths overall (on average most terror attacks cause 0 to 2 deaths)

# %%
df[df.iyear>2006].nkill.describe()
# Out:
# count    84904.000000
# mean         2.372326
# std         10.235468
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          2.000000
# max       1500.000000
# Name: nkill, dtype: float64

# %%
df[df.iyear > 2006].sort_values('nkill', ascending=False).nkill[:10]
# Out:
# 133286    1500.0
# 132993     670.0
# 136503     517.0
# 136045     500.0
# 27719      421.0
# 90276      400.0
# 21920      383.0
# 131118     315.0
# 134879     310.0
# 4304       300.0
# Name: nkill, dtype: float64

# %%
df[df.iyear == 2016].sort_values('nkill', ascending=False)[['iyear','imonth','iday','nkill','gname','attacktype1_txt','claimed','city','country_txt','summary']][:20].to_csv('../data/top-20-nkill-2016.csv')

# %% [markdown]
# #### Histogram of nkilled (lop outliers)

# %%
df[(df.iyear > 2006)&(df.nkill<300)].nkill.value_counts()[:10]
# Out:
# 0.0     40335
# 1.0     19344
# 2.0      8071
# 3.0      4164
# 4.0      2559
# 5.0      1732
# 6.0      1279
# 7.0       946
# 8.0       698
# 10.0      537
# Name: nkill, dtype: int64

# %%
sns.distplot(df[(df.iyear > 2006)&(df.nkill<300)].nkill)

# %%
df[(df.iyear > 2006)&(df.nkill<300)].nkill.hist(bins=100)

# %% [markdown]
#  ## Rise of the deadly hostage attack?

# %%
df[df.iyear > 2006].groupby(['iyear','attacktype1_txt']).nkill.sum()
# Out:
# iyear  attacktype1_txt
# 2007   Armed Assault                           3183.00
#        Assassination                            190.00
#        Bombing/Explosion                       8717.00
#        Facility/Infrastructure Attack           117.00
#        Hijacking                                  1.00
#        Hostage Taking (Barricade Incident)       10.00
#        Hostage Taking (Kidnapping)              450.00
#        Unarmed Assault                            7.00
#        Unknown                                  161.00
# 2008   Armed Assault                           2878.00
#        Assassination                            365.00
#        Bombing/Explosion                       5211.00
#        Facility/Infrastructure Attack            37.00
#        Hijacking                                 19.00
#        Hostage Taking (Barricade Incident)        0.00
#        Hostage Taking (Kidnapping)              336.00
#        Unarmed Assault                           16.00
# ...

# %%
df[(df.iyear > 2006)&(df.attacktype1_txt.isin(['Hostage Taking (Barricade Incident)','Hostage Taking (Kidnapping)']))].groupby('iyear').eventid.count()
# Out:
# iyear
# 2007     229
# 2008     394
# 2009     283
# 2010     397
# 2011     363
# 2012     370
# 2013     654
# 2014    1441
# 2015    1264
# 2016    1159
# Name: eventid, dtype: int64

# %%
df[(df.iyear > 2006)&(df.attacktype1_txt.isin(['Hostage Taking (Barricade Incident)','Hostage Taking (Kidnapping)']))].groupby('iyear').nkill.sum()
# Out:
# iyear
# 2007     460.00
# 2008     336.00
# 2009     364.00
# 2010     413.00
# 2011     283.00
# 2012     712.75
# 2013    1111.50
# 2014    7389.00
# 2015    3797.00
# 2016    4907.00
# Name: nkill, dtype: float64

# %%
host_ct = df[(df.iyear > 2006)&(df.attacktype1_txt.isin(['Hostage Taking (Barricade Incident)','Hostage Taking (Kidnapping)']))].groupby('iyear').eventid.count()
host_ct.plot()
plt.ylabel("Incidents of incidents")
plt.title("Hostage attacks, 2007-2016")

# %%
host_percent = 100*(df[(df.iyear > 2006)&(df.attacktype1_txt.isin(['Hostage Taking (Barricade Incident)','Hostage Taking (Kidnapping)']))].groupby('iyear').eventid.count()) / (df[(df.iyear > 2006)].groupby('iyear').eventid.count())
host_percent.plot()
plt.ylabel("percent of incidents")
plt.title("Hostage attacks as percent of all incidents, 2007-2016")

# %% [markdown]
# ## Which group uses most hostage?

# %%
df[(df.iyear ==2016)].groupby(['gname']).apply(lambda x:sum(x['attacktype1_txt'].isin(['Hostage Taking (Barricade Incident)','Hostage Taking (Kidnapping)'])) / (1.0*len(x['attacktype1_txt']))).sort_values(ascending=False)

# %%
host_percent = 100*(df[(df.iyear > 2006)&(df.attacktype1_txt.isin(['Hostage Taking (Barricade Incident)','Hostage Taking (Kidnapping)']))].groupby('iyear').nkill.sum()) / (df[(df.iyear > 2006)].groupby('iyear').nkill.sum())
host_percent.plot()
plt.ylabel("percent of all deaths")
plt.title("Hostage attacks as a percent of all deaths, 2007-2016")

# %%
df[(df.iyear > 2006)&(df.attacktype1_txt.isin(['Hostage Taking (Barricade Incident)','Hostage Taking (Kidnapping)']))].groupby('gname').eventid.count().sort_values(ascending=False)[:10]
# Out:
# gname
# Unknown                                           1924
# Taliban                                            621
# Islamic State of Iraq and the Levant (ISIL)        516
# Communist Party of India - Maoist (CPI-Maoist)     283
# Al-Shabaab                                         272
# Maoists                                            204
# New People's Army (NPA)                            155
# Boko Haram                                         149
# Tehrik-i-Taliban Pakistan (TTP)                    136
# Huthi Extremists                                   126
# Name: eventid, dtype: int64

# %%
df[(df.iyear ==2016)&(df.attacktype1_txt.isin(['Hostage Taking (Barricade Incident)','Hostage Taking (Kidnapping)']))].groupby('gname').eventid.count().sort_values(ascending=False)[:10]
# Out:
# gname
# Unknown                                           239
# Islamic State of Iraq and the Levant (ISIL)       163
# Taliban                                           110
# Tripoli Province of the Islamic State              82
# Maoists                                            58
# Al-Shabaab                                         55
# New People's Army (NPA)                            30
# Communist Party of India - Maoist (CPI-Maoist)     25
# Abu Sayyaf Group (ASG)                             23
# Boko Haram                                         22
# Name: eventid, dtype: int64

# %%
df[(df.iyear ==2016)&(df.gname=='Islamic State of Iraq and the Levant (ISIL)')].groupby('attacktype1_txt').eventid.count().sort_values(ascending=False)[:10]
# Out:
# attacktype1_txt
# Bombing/Explosion                      965
# Hostage Taking (Kidnapping)            160
# Unknown                                144
# Armed Assault                          127
# Assassination                           25
# Facility/Infrastructure Attack           6
# Hostage Taking (Barricade Incident)      3
# Name: eventid, dtype: int64

# %%
df[(df.iyear ==2016)&(df.gname=='Islamic State of Iraq and the Levant (ISIL)')].groupby('attacktype1_txt').nkill.sum().sort_values(ascending=False)[:10]
# Out:
# attacktype1_txt
# Bombing/Explosion                      6694.0
# Hostage Taking (Kidnapping)            2736.0
# Unknown                                1088.0
# Armed Assault                           934.0
# Assassination                            65.0
# Hostage Taking (Barricade Incident)      53.0
# Facility/Infrastructure Attack            0.0
# Name: nkill, dtype: float64

# %% [markdown]
# #### Last 10 years, total number of deaths was 201,420

# %%
df[df.iyear > 2006].nkill.sum()
# Out:
# 201420.0

# %%
n_incidents = df[(df.iyear>2006)].eventid.count()
print "total number of incidents in the past 10 years:", n_incidents
print "number of incidents killing less than 10 in the past 10 years:", round(100*(df[(df.iyear>2006)&(df.nkill<10)].eventid.count() / float(n_incidents)),2), '%'
print "number of incidents killing more than 50 in the past 10 years:", round(100*(df[(df.iyear>2006)&(df.nkill>50)].eventid.count() / float(n_incidents)),2), '%'
print "number of incidents killing more than 100 in the past 10 years:", round(100*df[(df.iyear>2006)&(df.nkill>100)].eventid.count() / float(n_incidents),2), '%'
print "number of incidents killing more than 200 in the past 10 years:", round(100*df[(df.iyear>2006)&(df.nkill>200)].eventid.count() / float(n_incidents),2), '%'
# Out:
# total number of incidents in the past 10 years: 88254
# number of incidents killing less than 10 in the past 10 years: 91.29 %
# number of incidents killing more than 50 in the past 10 years: 0.36 %
# number of incidents killing more than 100 in the past 10 years: 0.09 %
# number of incidents killing more than 200 in the past 10 years: 0.03 %

# %%
n_deaths = df[(df.iyear>2006)].nkill.sum()
print "total number of deaths in the past 10 years:", n_deaths
print "number of deaths by incidents killing less than 10 in the past 10 years:", round(100*(df[(df.iyear>2006)&(df.nkill<10)].nkill.sum() / float(n_deaths)),2), '%'
print "number of deaths by incidents killing more than 10 in the past 10 years:", round(100*(df[(df.iyear>2006)&(df.nkill>=10)].nkill.sum() / float(n_deaths)),2), '%'
print "number of deaths by of incidents killing more than 50 in the past 10 years:", round(100*(df[(df.iyear>2006)&(df.nkill>50)].nkill.sum() / float(n_deaths)),2), '%'
print "number of deaths by of incidents killing more than 100 in the past 10 years:", round(100*df[(df.iyear>2006)&(df.nkill>100)].nkill.sum() / float(n_deaths),2), '%'
print "number of deaths by of incidents killing more than 200 in the past 10 years:", round(100*df[(df.iyear>2006)&(df.nkill>200)].nkill.sum() / float(n_deaths),2), '%'
# Out:
# total number of deaths in the past 10 years: 201420.0
# number of deaths by incidents killing less than 10 in the past 10 years: 46.34 %
# number of deaths by incidents killing more than 10 in the past 10 years: 53.66 %
# number of deaths by of incidents killing more than 50 in the past 10 years: 16.64 %
# number of deaths by of incidents killing more than 100 in the past 10 years: 8.45 %
# number of deaths by of incidents killing more than 200 in the past 10 years: 4.63 %

# %% [markdown]
# #### 2016, total number of deaths was 34,623

# %%
df[df.iyear == 2016].nkill.sum()
# Out:
# 34623.0

# %%
n_incidents = df[(df.iyear==2016)].eventid.count()
print "total number of incidents in 2016:", n_incidents
print "number of incidents killing 0 person:", round(100*(df[(df.iyear==2016)&(df.nkill==0)].eventid.count() / float(n_incidents)),2), '%'
print "number of incidents killing 1 person:", round(100*(df[(df.iyear==2016)&(df.nkill==1)].eventid.count() / float(n_incidents)),2), '%'
print "number of incidents killing less than 10 in 2016:", round(100*(df[(df.iyear==2016)&(df.nkill<10)].eventid.count() / float(n_incidents)),2), '%'
print "number of incidents killing more than 50 in 2016:", round(100*(df[(df.iyear==2016)&(df.nkill>50)].eventid.count() / float(n_incidents)),2), '%'
print "number of incidents killing more than 100 in 2016:", round(100*df[(df.iyear==2016)&(df.nkill>100)].eventid.count() / float(n_incidents),2), '%'
print "number of incidents killing more than 200 in 2016", round(100*df[(df.iyear==2016)&(df.nkill>200)].eventid.count() / float(n_incidents),2), '%'
# Out:
# total number of incidents in 2016: 13446
# number of incidents killing 0 person: 41.92 %
# number of incidents killing 1 person: 22.59 %
# number of incidents killing less than 10 in 2016: 88.04 %
# number of incidents killing more than 50 in 2016: 0.47 %
# number of incidents killing more than 100 in 2016: 0.09 %
# number of incidents killing more than 200 in 2016 0.04 %

# %%
n_deaths = df[(df.iyear==2016)].nkill.sum()
print "total number of deaths in 2016:", n_deaths
print "number of deaths by incidents killing less than 10 in 2016:", round(100*(df[(df.iyear==2016)&(df.nkill<10)].nkill.sum() / float(n_deaths)),2), '%'
print "number of deaths by incidents killing more or equal to 10 in 2016:", round(100*(df[(df.iyear==2016)&(df.nkill>=10)].nkill.sum() / float(n_deaths)),2), '%'
print "number of deaths by of incidents killing more than 50 in 2016:", round(100*(df[(df.iyear==2016)&(df.nkill>50)].nkill.sum() / float(n_deaths)),2), '%'
print "number of deaths by of incidents killing more than or 100 in 2016:", round(100*df[(df.iyear==2016)&(df.nkill>=100)].nkill.sum() / float(n_deaths),2), '%'
print "number of deaths by of incidents killing more than 200 in 2016:", round(100*df[(df.iyear==2016)&(df.nkill>200)].nkill.sum() / float(n_deaths),2), '%'
# Out:
# total number of deaths in 2016: 34623.0
# number of deaths by incidents killing less than 10 in 2016: 40.49 %
# number of deaths by incidents killing more or equal to 10 in 2016: 59.51 %
# number of deaths by of incidents killing more than 50 in 2016: 18.29 %
# number of deaths by of incidents killing more than or 100 in 2016: 8.55 %
# number of deaths by of incidents killing more than 200 in 2016: 5.55 %

# %%
df[(df.iyear > 2006)&(df.attacktype1_txt.isin(['Hostage Taking (Barricade Incident)','Hostage Taking (Kidnapping)']))].groupby('gname').eventid.count().sort_values(ascending=False)
# Out:
# gname
# Unknown                                                                     1924
# Taliban                                                                      621
# Islamic State of Iraq and the Levant (ISIL)                                  516
# Communist Party of India - Maoist (CPI-Maoist)                               283
# Al-Shabaab                                                                   272
# Maoists                                                                      204
# New People's Army (NPA)                                                      155
# Boko Haram                                                                   149
# Tehrik-i-Taliban Pakistan (TTP)                                              136
# Huthi Extremists                                                             126
# Tripoli Province of the Islamic State                                        123
# ...

# %%
df[(df.iyear > 2006)&(df.attacktype1_txt.isin(['Hostage Taking (Barricade Incident)','Hostage Taking (Kidnapping)']))].groupby('gname').nkill.sum().sort_values(ascending=False)
# Out:
# gname
# Islamic State of Iraq and the Levant (ISIL)                                 8599.0
# Taliban                                                                     1797.5
# Boko Haram                                                                  1386.0
# Unknown                                                                     1374.0
# Al-Shabaab                                                                   954.0
# Tehrik-i-Taliban Pakistan (TTP)                                              443.0
# Al-Nusrah Front                                                              415.0
# Al-Qaida in the Arabian Peninsula (AQAP)                                     376.0
# Sudan People's Liberation Movement in Opposition (SPLM-IO)                   342.0
# Murle Tribe                                                                  315.0
# Communist Party of India - Maoist (CPI-Maoist)                               252.0
# ...

# %%
df[(df.iyear > 2006)&(df.attacktype1_txt.isin(['Hostage Taking (Barricade Incident)','Hostage Taking (Kidnapping)']))].sort_values('nkill',ascending=False)[['iyear','imonth','iday','gname','nkill','city','country_txt','targtype1_txt','summary']][:20].to_csv('../data/top-20-hostage.csv')

# %% [markdown]
# ## Increase in use of hostage  over time?

# %%
host_percent = 100*(df[(df.iyear > 2006)&(df.attacktype1_txt.isin(['Hostage Taking (Barricade Incident)','Hostage Taking (Kidnapping)']))].groupby('iyear').nkill.sum()) / (df[(df.iyear > 2006) ].groupby('iyear').nkill.sum())
host_percent.plot()
plt.ylabel("percent of all deaths")
plt.ylim([0,30])
plt.title("Hostage attacks as a percent of all deaths by all grps, 2007-2016")

# %%
host_percent = 100*(df[(df.iyear > 2006)&(df.attacktype1_txt.isin(['Hostage Taking (Barricade Incident)','Hostage Taking (Kidnapping)']))].groupby('iyear').eventid.count()) / (df[(df.iyear > 2006)].groupby('iyear').eventid.count())
host_percent.plot()
plt.ylabel("percent of all events")
plt.ylim([0,30])
plt.title("Hostage attacks as a percent of all events by all grps, 2007-2016")

# %% [markdown]
# ## Increase in use of hostage by ISIL over time?

# %%
host_percent = 100*(df[(df.gname=='Islamic State of Iraq and the Levant (ISIL)')&(df.iyear > 2006)&(df.attacktype1_txt.isin(['Hostage Taking (Barricade Incident)','Hostage Taking (Kidnapping)']))].groupby('iyear').nkill.sum()) / (df[(df.iyear > 2006) & (df.gname == 'Islamic State of Iraq and the Levant (ISIL)')].groupby('iyear').nkill.sum())
host_percent.plot()
plt.ylabel("percent of all deaths")
plt.ylim([0,100])
plt.title("Hostage attacks as a percent of all deaths by ISIL, 2007-2016")

# %%
host_percent = 100*(df[(df.gname=='Islamic State of Iraq and the Levant (ISIL)')&(df.iyear > 2006)&(df.attacktype1_txt.isin(['Hostage Taking (Barricade Incident)','Hostage Taking (Kidnapping)']))].groupby('iyear').eventid.count()) / (df[(df.iyear > 2006) & (df.gname == 'Islamic State of Iraq and the Levant (ISIL)')].groupby('iyear').eventid.count())
host_percent.plot()
plt.ylabel("percent of all events")
plt.ylim([0,100])
plt.title("Hostage attacks as a percent of all events by ISIL, 2007-2016")

# %%
df[( df.iyear > 2006)& (df.attacktype1_txt.isin(['Hostage Taking (Barricade Incident)','Hostage Taking (Kidnapping)'])) & (df.ishostkid ==0)][['eventid','iyear','imonth','iday','summary','city','attacktype1_txt','ishostkid']].to_csv('../data/not-hostkid.csv', encoding='utf8')

# %%
df[( df.iyear >= 2012)].groupby('iyear').nhostkid.sum().plot(label='number hostages')
df[( df.iyear >= 2012)&(df.ishostkid==1)].groupby('iyear').eventid.count().plot(label='number of kidnappings')
df[( df.iyear >= 2012)].groupby('iyear').eventid.count().plot(label='number of all attacks')
plt.title('Total number of people taken hostage, all groups')
plt.legend()

# %%
print df[( df.iyear > 2006)].groupby('iyear').ransomamt.sum().plot()
plt.title('total randsom amt demanded (us dollars), all groups')
# Out:
# Axes(0.125,0.125;0.775x0.755)

# %%
print df[( df.iyear > 2006)& (df.gname=='Islamic State of Iraq and the Levant (ISIL)')].groupby('iyear').ransomamt.sum().plot()
plt.title('total randsom amt demanded (us dollars), ISIL')
# Out:
# Axes(0.125,0.125;0.775x0.755)

# %%
df[(df.iyear > 2006) & (df.attacktype1_txt.isin(['Hostage Taking (Barricade Incident)','Hostage Taking (Kidnapping)']))].sort_values('nkill', ascending=False)[['iyear','imonth','iday','gname','nkill','attacktype1_txt','city','country_txt','ransom','nreleased']][:10]
# Out:
#         iyear  imonth  iday  \
# 133286   2014       6    12
# 136503   2014       8    19
# 136045   2014       8     3
# 27719    2016      12    10
# 134879   2014       7    17
# 4304     2015       4     9
# 16286    2016       2     7
# 130195   2014       4    15
# 25927    2016      10    21
# 6055     2015       5    21
#
#                                                     gname   nkill  \
# 133286        Islamic State of Iraq and the Levant (ISIL)  1500.0
# 136503        Islamic State of Iraq and the Levant (ISIL)   517.0
# 136045        Islamic State of Iraq and the Levant (ISIL)   500.0
# 27719         Islamic State of Iraq and the Levant (ISIL)   421.0
# 134879        Islamic State of Iraq and the Levant (ISIL)   310.0
# 4304          Islamic State of Iraq and the Levant (ISIL)   300.0
# 16286         Islamic State of Iraq and the Levant (ISIL)   300.0
# 130195  Sudan People's Liberation Movement in Oppositi...   287.0
# ...

# %%
set(df.weaptype1_txt)
# Out:
# {u'Biological',
#  u'Chemical',
#  u'Explosives/Bombs/Dynamite',
#  u'Fake Weapons',
#  u'Firearms',
#  u'Incendiary',
#  u'Melee',
#  u'Other',
#  u'Radiological',
#  u'Sabotage Equipment',
#  u'Unknown',
#  u'Vehicle (not to include vehicle-borne explosives, i.e., car or truck bombs)'}

# %% [markdown]
# ## What do most mass kidnapping events look like?

# %%
len(df[(df.ishostkid ==1) & (df.iyear==2016)])
# Out:
# 1202

# %%
df[(df.ishostkid ==1) & (df.iyear==2016)].sort_values("nhostkid", ascending=False)\
    [['iyear','imonth','iday','city','country_txt','nhostkid','nkill','summary','targtype1_txt','scite1']][:30]
# Out:
#        iyear  imonth  iday               city   country_txt  nhostkid  nkill  \
# 23143   2016       8     4   Hawijah district          Iraq    3000.0   97.0
# 23517   2016       8    12             Manbij         Syria    2000.0    NaN
# 20770   2016       6     1         Saqlawiyah          Iraq    1500.0   49.0
# 27870   2016      12    16             Aleppo         Syria     800.0    4.0
# 16286   2016       2     7              Mosul          Iraq     300.0  300.0
# 26002   2016      10    24             Quetta      Pakistan     300.0   67.0
# 25927   2016      10    21              Mosul          Iraq     284.0  284.0
# 19054   2016       4    21              Mosul          Iraq     250.0  250.0
# 17410   2016       3     8              Mosul          Iraq     215.0    NaN
# 23887   2016       8    24              Kabul   Afghanistan     201.0   19.0
# 26310   2016      11     2           Tal Afar          Iraq     195.0    NaN
# ...

# %%
df.n

# %% [markdown]
# ## is hostkid is 1, but it is attack type is not  kidnapping

# %%
df[(df.iyear==2016) & (~df.attacktype1_txt.isin(['Hostage Taking (Barricade Incident)','Hostage Taking (Kidnapping)']))& (df.ishostkid==1)][['attacktype1_txt','summary']]
# Out:
#                       attacktype1_txt  \
# 14994                   Assassination
# 15256                   Assassination
# 15627                   Assassination
# 15711                       Hijacking
# 15901                       Hijacking
# 15995                       Hijacking
# 16329                   Assassination
# 17316                   Assassination
# 17438                       Hijacking
# 17926                       Hijacking
# 17988                       Hijacking
# 18101                       Hijacking
# 18449                       Hijacking
# 18506                   Assassination
# 18719                       Hijacking
# 18723                       Hijacking
# 18743                   Assassination
# 18807                       Hijacking
# 19128                   Assassination
# 19338                       Hijacking
# 19350                   Assassination
# 19429                   Assassination
# 19940                   Assassination
# ...

# %% [markdown]
# ## is hostkid is 0, but it is attack type kidnapping

# %%
df[(df.iyear==2016) & (df.attacktype1_txt.isin(['Hostage Taking (Barricade Incident)','Hostage Taking (Kidnapping)']))& (df.ishostkid==0)][['summary']]
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                              summary
# 14880                                                                                                                                           01/02/2016: Assailants attempted to abduct 15 traders in Mandangre village, Meghalaya state, India. The traders resisted and the assailants opened fire, injuring one person. No group claimed responsibility; however, sources attributed the incident to A'chik Songna An'pachakgipa Kotok (ASAK).
# ...

# %%
len(df[(df.iyear==2016) & (df.ishostkid==1)& (~df.attacktype1_txt.isin(['Hostage Taking (Barricade Incident)','Hostage Taking (Kidnapping)']))])
# Out:
# 68

# %% [markdown]
#  ## Countrys with most abductions/kidnappings

# %%
df[(df.ishostkid ==1) & (df.iyear==2016) &(df.nhostkid>50)].country_txt.value_counts()
# Out:
# Iraq            22
# Afghanistan     10
# Syria            9
# Somalia          2
# Libya            1
# Burkina Faso     1
# Pakistan         1
# Name: country_txt, dtype: int64

# %%
df[(df.ishostkid ==1) & (df.iyear==2016) &(df.nkill>50)].country_txt.value_counts()
# Out:
# Iraq                        8
# Afghanistan                 2
# Central African Republic    1
# Cameroon                    1
# Nigeria                     1
# Syria                       1
# Pakistan                    1
# Somalia                     1
# Name: country_txt, dtype: int64

# %%
df[(df.ishostkid ==1) & (df.iyear==2016) &(df.nkill>10)].gname.value_counts()
# Out:
# Islamic State of Iraq and the Levant (ISIL)                                 48
# Murle Tribe                                                                 11
# Taliban                                                                      8
# Boko Haram                                                                   4
# Al-Shabaab                                                                   4
# Khorasan Chapter of the Islamic State                                        2
# Lashkar-e-Jhangvi                                                            1
# Opponents of disabled people                                                 1
# Islamic State in Bangladesh                                                  1
# Democratic Front for the Liberation of Rwanda (FDLR)                         1
# Adan-Abyan Province of the Islamic State                                     1
# Unknown                                                                      1
# ...

# %%
df[(df.ishostkid ==1) &(df.nkill>10)&(df.iyear>2006)].groupby('iyear').eventid.count().plot()
plt.title('Hostage/kidnappings killing more than 10 people (out of all incidents)')

# %%
df[(df.ishostkid ==1) &(df.nkill>50)&(df.iyear>2006)].groupby('iyear').eventid.count().plot()
plt.title('Hostage/kidnappings killing more than 50 people (out of all incidents)')

# %%
df[(df.ishostkid ==1) &(df.nhostkid>50)&(df.iyear>2006)].groupby('iyear').eventid.count().plot()
plt.title('Hostage/kidnappings involving more than 50 people (out of all incidents)')
plt.ylabel("Number of incidents")

# %%
df[(df.ishostkid ==1) & (df.iyear>2006)].groupby('iyear').nhostkid.sum().plot()
plt.title('Total number of victims of hostage/kidnappings(out of all incidents)')
plt.ylabel("Number of victims")

# %%
df[(df.ishostkid ==1) &(df.nhostkid>100)&(df.iyear>2006)].groupby('iyear').eventid.count().plot()
plt.title('Hostage/kidnappings involving more than 100 people (out of all incidents)')
plt.ylabel("Number of incidents")

# %%
by_country = df[(df.ishostkid ==1) &(df.nkill>100)&(df.iyear>2006)].groupby(['iyear','country_txt']).size().reset_index(name='count')
by_country.pivot(index='iyear', columns='country_txt').plot(kind='area',colormap='Set1')
plt.title("Hostage / Kidnapping incidents involving more than 100")
#by_country
#plt.xticks([2012,2013,2014,2015,2016])
#df[(df.ishostkid ==1) &(df.nkill>50)].groupby(['iyear','country_txt']).size()

# %%
by_country = df[(df.ishostkid ==1) &(df.nkill>100)&(df.iyear>2006)].groupby(['iyear','country_txt']).size().reset_index(name='count')
by_country.pivot(index='iyear', columns='country_txt').plot(kind='area',colormap='Set1')
plt.title("Hostage / Kidnapping incidents killing more than 100")
#by_country
#plt.xticks([2012,2013,2014,2015,2016])
#df[(df.ishostkid ==1) &(df.nkill>50)].groupby(['iyear','country_txt']).size()

# %%
df[(df.country_txt=='Iraq')&(df.ishostkid ==1) &(df.nkill>50)].groupby(['iyear']).eventid.count().plot()
plt.title('Host/Kidnapping events killing more than 50 in Iraq')
#by_country.pivot(index='iyear', columns='country_txt').plot(kind='area')
#by_country
#df[(df.ishostkid ==1) &(df.nkill>50)].groupby(['iyear','country_txt']).size()

# %%
df[(df.gname=='Islamic State of Iraq and the Levant (ISIL)')&(df.ishostkid ==1)&(df.iyear>2006)].groupby(['iyear']).eventid.count().plot()
plt.title("Number of hostage/kidnapping by ISIL")

plt.xticks([2012,2013,2014,2015,2016])
# Out:
# ([<matplotlib.axis.XTick at 0x15be0e910>,
# ...
#  <a list of 5 Text xticklabel objects>)

# %%
df[(df.gname=='Islamic State of Iraq and the Levant (ISIL)')&(df.ishostkid ==1)&(df.iyear>2006)].groupby(['iyear']).nkill.sum().plot()
plt.title("Number of deaths by hostage/kidnapping by ISIL")

plt.xticks([2012,2013,2014,2015,2016])
# Out:
# ([<matplotlib.axis.XTick at 0x1683f4950>,
# ...
#  <a list of 5 Text xticklabel objects>)

# %%
df[(df.gname=='Al-Qaida in Iraq')&(df.ishostkid ==1)].groupby(['iyear']).eventid.count().plot()
plt.title("Number of hostage/kidnapping by Al-Qaida in Iraq")

# %%
df[(df.gname=='Abu Sayyaf Group (ASG)')&(df.ishostkid ==1)].groupby(['iyear']).eventid.count()
#plt.title("Number of hostage/kidnapping by Abu Sayyaf")
# Out:
# iyear
# 1994     3
# 1995     6
# 1997     1
# 1998     4
# 1999     5
# 2000     8
# 2001     7
# 2002     3
# 2003     1
# 2004     2
# 2006     2
# 2007     1
# 2008    13
# 2009     4
# 2010     6
# 2011     3
# 2012     7
# 2013    17
# 2014    26
# 2015    20
# 2016    27
# Name: eventid, dtype: int64

# %%
df[(df.gname=='Abu Sayyaf Group (ASG)')&(df.ishostkid ==1)].groupby(['iyear']).nkill.sum().plot()
plt.title("Number of deaths by hostage/kidnapping by Abu Sayyaf")

# %%
df[(df.gname=='Boko Haram')&(df.ishostkid ==1)].groupby(['iyear']).eventid.count().plot()
plt.title("Number of hostage/kidnapping by Boko Haram")

# %%
df[(df.gname=='Boko Haram')&(df.ishostkid ==1)].groupby(['iyear']).nkill.sum().plot()
plt.title("Number of deaths by hostage/kidnapping by Boko Haram")

# %% [markdown]
# ## How many kidnappings are the large kind?

# %%
sns.distplot(df[(df.ishostkid ==1)&(df.iyear==2016)].nhostkid.value_counts()) 
plt.title('Hostage/kidnappings in 2016')

# %%
 sns.distplot(df[(df.ishostkid ==1)&(df.iyear==2016)].nkill.value_counts()) 
plt.title('Hostage/kidnappings in 2016')

# %% [markdown]
# ## Paragraphs 1 and 2

# %%
df[df.iyear>2006].groupby('iyear').eventid.count()
# Out:
# iyear
# 2007     3241
# 2008     4787
# 2009     4721
# 2010     4821
# 2011     5067
# 2012     8498
# 2013    11990
# 2014    16840
# 2015    14843
# 2016    13446
# Name: eventid, dtype: int64

# %%
df[df.iyear>2006].groupby('iyear').nkill.sum()
# Out:
# iyear
# 2007    12836.0
# 2008     9093.0
# 2009     9271.0
# 2010     7720.0
# 2011     8198.0
# 2012    15432.0
# 2013    22226.0
# 2014    43550.0
# 2015    38471.0
# 2016    34623.0
# Name: nkill, dtype: float64

# %%
df[df.iyear==2016].country_txt.value_counts()[:10]
# Out:
# Iraq           3356
# Afghanistan    1613
# India          1016
# Pakistan        859
# Philippines     630
# Somalia         590
# Turkey          539
# Nigeria         531
# Yemen           519
# Syria           469
# Name: country_txt, dtype: int64

# %%
df[df.iyear==2016].groupby(['country_txt']).nkill.sum().sort_values(ascending=False)[:5]
# Out:
# country_txt
# Iraq           12186.0
# Afghanistan     6106.0
# Syria           2741.0
# Nigeria         2164.0
# Somalia         1558.0
# Name: nkill, dtype: float64

# %%
df[df.iyear==2016].groupby(['country_txt']).nkill.sum().sort_values(ascending=False)[:5].sum() / 34623.0
# Out:
# 0.7149871472720446

# %%
df[(df.iyear==2016)&(df.ishostkid==1)].nkill.sum()
# Out:
# 4958.0

# %% [markdown]
# ## Deadliest attacks 2016

# %%
df[df.iyear==2016].sort_values('nkill',ascending=False)[:10][['nkill','nhostkid','attacktype1_txt','targtype1_txt','country_txt','scite1','summary']][:10]
# Out:
#        nkill  nhostkid              attacktype1_txt  \
# 27719  421.0       NaN  Hostage Taking (Kidnapping)
# 21920  383.0       NaN            Bombing/Explosion
# 16286  300.0     300.0  Hostage Taking (Kidnapping)
# 25927  284.0     284.0  Hostage Taking (Kidnapping)
# 23750  283.0       NaN                Armed Assault
# 19054  250.0     250.0  Hostage Taking (Kidnapping)
# 26074  190.0     190.0  Hostage Taking (Kidnapping)
# 25254  154.0       NaN                Armed Assault
# 15360  141.0      12.0  Hostage Taking (Kidnapping)
# 27363  130.0     130.0  Hostage Taking (Kidnapping)
#
#                      targtype1_txt  country_txt  \
# 27719  Private Citizens & Property        Syria
# 21920                     Business         Iraq
# 16286                       Police         Iraq
# 25927  Private Citizens & Property         Iraq
# 23750  Private Citizens & Property  South Sudan
# 19054  Private Citizens & Property         Iraq
# ...

# %%
df[(df.iyear==2016)&(df.nkill>50)].nkill.sum()
# Out:
# 6331.0

# %%
df[(df.iyear==2016)].nkill.sum()
# Out:
# 34623.0

# %%
df[(df.iyear==2016)].eventid.count()
# Out:
# 13446

# %%
df[(df.iyear==2016)].country_txt.value_counts()[:10]
# Out:
# Iraq           3356
# Afghanistan    1613
# India          1016
# Pakistan        859
# Philippines     630
# Somalia         590
# Turkey          539
# Nigeria         531
# Yemen           519
# Syria           469
# Name: country_txt, dtype: int64

# %%
df[(df.iyear==2016)].nkill.sum()
# Out:
# 34623.0

# %%
df[(df.iyear==2016)].groupby('country_txt').nkill.sum().sort_values(ascending=False)[:10]
# Out:
# country_txt
# Iraq           12186.0
# Afghanistan     6106.0
# Syria           2741.0
# Nigeria         2164.0
# Somalia         1558.0
# Yemen           1515.0
# Pakistan        1111.0
# Turkey          1002.0
# South Sudan      633.0
# Libya            630.0
# Name: nkill, dtype: float64

# %%
df[df.iyear==2016].sort_values('nhostkid',ascending=False)[['summary','nhostkid','nkill','scite1','scite2']][:20]
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       summary  \
# ...

# %%
df[(df.iyear==2016)&(df.country_txt=='Iraq')].nkill.sum()
# Out:
# 12186.0

# %%
df[(df.iyear==2016)&(df.nhostkid>50)].eventid.count()
# Out:
# 46

# %%
df[(df.ishostkid==1)&(df.iyear==2016)].groupby('gname').eventid.count().sort_values(ascending=False)
# Out:
# gname
# Unknown                                                                     245
# Islamic State of Iraq and the Levant (ISIL)                                 164
# Taliban                                                                     114
# Tripoli Province of the Islamic State                                        84
# Maoists                                                                      62
# Al-Shabaab                                                                   59
# New People's Army (NPA)                                                      36
# Abu Sayyaf Group (ASG)                                                       27
# Communist Party of India - Maoist (CPI-Maoist)                               27
# Boko Haram                                                                   22
# Janjaweed                                                                    21
# Huthi Extremists                                                             19
# ...

# %%
len(set(df[df.iyear==2016].gname))
# Out:
# 328

# %%
df[df.iyear==2016].nkill.sum()
# Out:
# 34623.0

# %%
df[(df.iyear>2006)].groupby('iyear').eventid.count()
# Out:
# iyear
# 2007     3241
# 2008     4787
# 2009     4721
# 2010     4821
# 2011     5067
# 2012     8498
# 2013    11990
# 2014    16840
# 2015    14843
# 2016    13446
# Name: eventid, dtype: int64

# %%
df[(df.nhostkid>0)&(df.iyear>2006)].groupby('iyear').nhostkid.sum()
# Out:
# iyear
# 2007     1934.0
# 2008     3315.0
# 2009     6515.0
# 2010     2352.0
# 2011     2170.0
# 2012     1611.0
# 2013     3343.0
# 2014    11842.0
# 2015    13095.0
# 2016    18791.0
# Name: nhostkid, dtype: float64

# %%
df[(df.ishostkid==1)&(df.iyear>=2012)&(df.nhostkid>50)].groupby('iyear').eventid.count()
# Out:
# iyear
# 2012     3
# 2013     4
# 2014    35
# 2015    52
# 2016    46
# Name: eventid, dtype: int64

# %%
df[(df.ishostkid==1)&(df.iyear>=2012)].groupby('iyear').eventid.count()
# Out:
# iyear
# 2012     380
# 2013     664
# 2014    1481
# 2015    1337
# 2016    1202
# Name: eventid, dtype: int64

# %%
(df[(df.ishostkid==1)&(df.iyear>=2012)].groupby('iyear').nhostkid.sum() )/(df[(df.ishostkid==1)&(df.iyear>=2012)].groupby('iyear').eventid.count())
# Out:
# iyear
# 2012     1.373684
# 2013     1.754518
# 2014     0.977043
# 2015     9.794316
# 2016    15.633111
# dtype: float64

# %%
df[(df.ishostkid==1)&(df.iyear>=2012)].sort_values('ransompaid', ascending=False)[:10][['summary', 'ransomamt','ransompaid','scite1']]
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     summary  \
# ...

# %%
abu_sayyaf = df[(df.iyear>=2000)&(df.gname=='Abu Sayyaf Group (ASG)')].groupby(['iyear', 'attacktype1_txt']).size().reset_index(name='count')
abu_sayyaf.pivot(index='iyear', columns='attacktype1_txt').plot(kind='area',colormap='Set1')

# %%
df[(df.iyear>=2000)&(df.gname=='Abu Sayyaf Group (ASG)')&(df.ishostkid==1)].groupby(['iyear']).size()
# Out:
# iyear
# 2000     8
# 2001     7
# 2002     3
# 2003     1
# 2004     2
# 2006     2
# 2007     1
# 2008    13
# 2009     4
# 2010     6
# 2011     3
# 2012     7
# 2013    17
# 2014    26
# 2015    20
# 2016    27
# dtype: int64

# %%
df[(df.iyear>=2000)&(df.gname=='Abu Sayyaf Group (ASG)')&(df.ishostkid==1)].groupby(['iyear']).eventid.count().plot()

# %%
df[(df.iyear>=2000)&(df.gname=='Abu Sayyaf Group (ASG)')&(df.ishostkid==1)].groupby(['iyear']).size()
# Out:
# iyear
# 2000     8
# 2001     7
# 2002     3
# 2003     1
# 2004     2
# 2006     2
# 2007     1
# 2008    13
# 2009     4
# 2010     6
# 2011     3
# 2012     7
# 2013    17
# 2014    26
# 2015    20
# 2016    27
# dtype: int64

# %%
df[(df.iyear==2005)&(df.ishostkid==1)].groupby(['gname']).size().sort_values(ascending=False)[:10]
# Out:
# gname
# Unknown                                             59
# Taliban                                             13
# Maoists                                             11
# Al-Qaida in Iraq                                     8
# Liberation Tigers of Tamil Eelam (LTTE)              6
# Salafist Group for Preaching and Fighting (GSPC)     5
# Ansar al-Sunna                                       4
# Algerian Islamic Extremists                          3
# Lashkar-e-Taiba (LeT)                                3
# National Liberation Army of Colombia (ELN)           2
# dtype: int64

# %%
df[(df.iyear>=1990)&(df.gname=='Algerian Islamic Extremists')&(df.ishostkid==1)][['summary','ransomamt']]
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    summary  \
# ...

# %%
df[(df.iyear>=1990)&(df.gname.str.contains('Al Qaeda'))&(df.ishostkid==1)].groupby(['iyear']).eventid.count().plot(label='hostkid')
df[(df.iyear>=1990)& (df.gname.str.contains('Al Qaeda'))].groupby(['iyear']).eventid.count().plot(label='events') 
plt.legend()
#plt.xticks(xrange(1990,2016,2))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-d30f68e52f18> in <module>()
# ----> 1 df[(df.iyear>=1990)&(df.gname.str.contains('Al Qaeda'))&(df.ishostkid==1)].groupby(['iyear']).eventid.count().plot(label='hostkid')
#       2 df[(df.iyear>=1990)& (df.gname.str.contains('Al Qaeda'))].groupby(['iyear']).eventid.count().plot(label='events')
#       3 plt.legend()
#       4 #plt.xticks(xrange(1990,2016,2))
#
# /usr/local/lib/python3.6/site-packages/pandas/plotting/_core.py in __call__(self, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    2441                            colormap=colormap, table=table, yerr=yerr,
#    2442                            xerr=xerr, label=label, secondary_y=secondary_y,
# ...

# %%
(df[(df.iyear>=1990)&(df.gname=='Al-Qaida in Iraq')&(df.ishostkid==1)].groupby(['iyear']).eventid.count() / df[(df.iyear>=1990)&(df.gname=='Al-Qaida in Iraq')].groupby(['iyear']).eventid.count()).fillna(0).plot()
#plt.xticks(xrange(1990,2016,2))
plt.title("al-qaida in iraq ratio hostage to overall")

# %%
df[(df.iyear>=1990)&(df.gname=='Al-Qaida in Iraq')&(df.ishostkid==1)].groupby(['iyear']).eventid.count().plot()

# %%
df[(df.iyear>=2012)&(df.ishostkid==1)].groupby(['iyear']).nhostkid.sum()
# Out:
# iyear
# 2012      522.0
# 2013     1165.0
# 2014     1447.0
# 2015    13095.0
# 2016    18791.0
# Name: nhostkid, dtype: float64

# %% [markdown]
# ##### df[(df.iyear>=2012)&(df.gname=='Abu Sayyaf Group (ASG)')&(df.ishostkid==1)].groupby(['iyear']).ransomamt.sum()

# %%
df[(df.iyear>=2000)&(df.gname=='Abu Sayyaf Group (ASG)')].groupby(['iyear','attacktype1_txt']).size()
# Out:
# iyear  attacktype1_txt
# 2000   Armed Assault                           3
#        Assassination                           1
#        Bombing/Explosion                       6
#        Hostage Taking (Kidnapping)             8
# 2001   Armed Assault                           4
#        Bombing/Explosion                       4
#        Hostage Taking (Barricade Incident)     1
#        Hostage Taking (Kidnapping)             5
# 2002   Armed Assault                           5
#        Assassination                           1
#        Bombing/Explosion                       8
#        Hostage Taking (Kidnapping)             3
# 2003   Armed Assault                           1
#        Bombing/Explosion                       3
#        Hostage Taking (Kidnapping)             1
# 2004   Armed Assault                           1
#        Bombing/Explosion                       3
#        Hostage Taking (Kidnapping)             2
# 2005   Armed Assault                           1
# ...

# %%
df[(df.iyear==2016)&(df.doubtterr==0)&(df.region_txt.isin(['Western Europe','North America']))][['nkill','summary','country_txt']].sort_values('nkill',ascending=False)[:10]
# Out:
#        nkill  \
# 22312   87.0
# 21168   50.0
# 17933   18.0
# 17934   17.0
# 27943   12.0
# 22583   10.0
# 22085    6.0
# 22414    4.0
# 22773    3.0
# 21210    3.0
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 summary  \
# ...

# %%
western_fatal=df[(df.iyear==2016)&(df.doubtterr==0)&(df.nkill>0)&(df.region_txt.isin(['Western Europe','North America']))]

# %%
western_fatal['non_terr'] = western_fatal['nkill']-western_fatal['nkillter']
# Out:
# /usr/local/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
western_fatal[western_fatal.nkill==1].eventid.count()
# Out:
# 26

# %%
western_fatal[western_fatal.non_terr ==1].eventid.count()
# Out:
# 18

# %%
western_fatal[western_fatal.non_terr == 0].eventid.count()
# Out:
# 9

# %%
western_fatal[western_fatal.non_terr>0].eventid.count()
# Out:
# 27

# %%
len(set(df[df.iyear==2016].country_txt))
# Out:
# 108

# %%
len(set(df[df.iyear==2016].columns))
# Out:
# 137

# %%
df[df.iyear==2016].country_txt.value_counts()[:10].index
# Out:
# Index([u'Iraq', u'Afghanistan', u'India', u'Pakistan', u'Philippines',
#        u'Somalia', u'Turkey', u'Nigeria', u'Yemen', u'Syria'],
#       dtype='object')

# %%
df[df.iyear==2016].groupby('country_txt').nkill.sum().sort_values(ascending=False)[:5].index
# Out:
# Index([u'Iraq', u'Afghanistan', u'Syria', u'Nigeria', u'Somalia'], dtype='object', name=u'country_txt')

# %%
(df[(df.iyear>=2012)&(df.ishostkid==1)].groupby('iyear').nhostkid.sum() / df[(df.iyear>=2012)&(df.ishostkid==1)].groupby('iyear').eventid.count()).plot()
plt.xticks(xrange(2012,2016))
# Out:
# ([<matplotlib.axis.XTick at 0x1848b4410>,
# ...
#  <a list of 4 Text xticklabel objects>)

# %%
df[(df.iyear>=2012)&(df.nhostkid>0)][['iyear','imonth','iday','nhostkid']].to_csv("../data/2012-2016-nhostkid-date.csv")

# %%
df[(df.iyear==2004)&(df.ishostkid==1)].sort_values("nhostkid",ascending=False)[['summary','nhostkid','gname']][:10]
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          summary  \
# ...

# %%
df[(df.gname=='Red Brigades')&(df.ishostkid==1)].groupby('iyear').eventid.count().plot()

# %%
 df[(df.gname=='Abu Sayyaf Group (ASG)')&(df.ishostkid==1)].groupby('iyear').eventid.count()
# Out:
# iyear
# 1994     3
# 1995     6
# 1997     1
# 1998     4
# 1999     5
# 2000     8
# 2001     7
# 2002     3
# 2003     1
# 2004     2
# 2006     2
# 2007     1
# 2008    13
# 2009     4
# 2010     6
# 2011     3
# 2012     7
# 2013    17
# 2014    26
# 2015    20
# 2016    27
# Name: eventid, dtype: int64

# %%
df[df.iyear>=2016].sort_values("nkill", ascending=False)[:20][['country_txt','nhostkid','summary','nkill','scite1']]
# Out:
#        country_txt  nhostkid  \
# 27719        Syria       NaN
# 21920         Iraq       NaN
# 16286         Iraq     300.0
# 25927         Iraq     284.0
# 23750  South Sudan       NaN
# 19054         Iraq     250.0
# 26074         Iraq     190.0
# 25254  Afghanistan       NaN
# 15360      Somalia      12.0
# 27363         Iraq     130.0
# 14969         Iraq       NaN
# 21076      Somalia       NaN
# 27334         Iraq     100.0
# 24516         Iraq       NaN
# 27190         Iraq       NaN
# 23143         Iraq    3000.0
# 25569  Afghanistan      24.0
# 15912      Nigeria       NaN
# 22312       France       NaN
# 24241  Afghanistan       NaN
#
# ...

# %%
df[(df.iyear==2016) & (df.imonth==9) & (df.iday == 21)].sort_values('nkill',ascending=False)[['nkill','summary','country_txt','gname','attacktype1_txt']]
# Out:
#        nkill  \
# 24779      9
# 24774      4
# 24784      3
# 24785      3
# 24920      2
# 24776      2
# 24777      2
# 24780      2
# 24782      1
# 24772      1
# 24889      1
# 24781      1
# 24778      1
# 24854      0
# 24864      0
# 24863      0
# 24865      0
# 24862      0
# 24861      0
# 24860      0
# 24859      0
# 24858      0
# 24857      0
# 24856      0
# 24855      0
# 24771      0
# 24853      0
# 24852      0
# 24851      0
# 24850      0
# 24849      0
# 24848      0
# 24867      0
# 24847      0
# 24846      0
# 24845      0
# 24844      0
# 24843      0
# 24866      0
# 24874      0
# 24868      0
# 24882      0
# 24897      0
# 24896      0
# 24895      0
# 24894      0
# 24893      0
# 24892      0
# 24887      0
# 24886      0
# 24885      0
# 24884      0
# 24883      0
# 24881      0
# 24869      0
# 24880      0
# 24879      0
# 24878      0
# 24877      0
# 24876      0
# 24875      0
# 24841      0
# 24873      0
# 24872      0
# 24871      0
# ...

# %%
df[(df.iyear==2016) & (df.imonth==1) & (df.iday == 15) &(df.country_txt=='Somalia')].sort_values('nkill',ascending=False)[['summary']]
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            summary
# ...

# %%
df[(df.iyear==2016) &  (df.country_txt=='Nigeria')].groupby(["imonth","iday"]).eventid.count().sort_values(ascending=False)
# Out:
# imonth  iday
# 3       13      25
# 11      15      15
# 7       12       9
# 6       27       9
# 5       30       8
# 7       4        8
# 1       24       7
# 3       10       7
# 2       24       7
# 9       26       6
# 6       20       6
# 11      19       6
# 6       23       6
# 3       8        6
# 11      23       5
# 7       8        5
# 8       19       5
# 7       7        5
# 2       11       5
# 5       20       5
#         24       5
# 10      27       5
#         29       4
# 11      13       4
# 4       22       4
# 6       21       4
# 7       10       4
# 11      8        4
# 9       25       4
# 5       8        4
# 2       7        4
# 11      18       4
# 7       18       4
# 5       28       3
# 2       5        3
# 7       20       3
# 5       16       3
# 12      18       3
# 8       1        3
# 1       27       3
# 6       18       3
# 11      14       3
# 10      14       3
# 1       15       3
# 5       29       3
#         31       3
# ...

# %%
df[(df.iyear==2016)&(df.ishostkid==1)&(df.nhostkid>0)&(df.gname=="Islamic State of Iraq and the Levant (ISIL)")][['summary','nkill','nhostkid','country_txt','targtype1_txt']].nkill.sum()
# Out:
# 2313.0

# %%
df[(df.iyear==2016)&(df.nhostkid>50)][['iyear','imonth','iday','nhostkid','nkill','city','country_txt','gname','summary']].sort_values("nhostkid",ascending=False).to_csv('../data/2016-hostkid-50-or-more.csv')

# %%
df[(df.iyear==2016)&(df.ishostkid==1)].eventid.count()
# Out:
# 1202

# %%
df.gname.to_csv("../data/gnames.csv",index=False)

# %%
df[(df.iyear==2016)&(df.nkill==1)&(df.nkillter ==1)].eventid.count()
# Out:
# 310

# %%
df[(df.iyear==2016)&(df.nkill==1)].eventid.count()
# Out:
# 3037

# %%
df[(df.iyear==2016)].eventid.count()
# Out:
# 13446

# %%
df[(df.iyear==2016)&(df.nkill==0)].eventid.count()
# Out:
# 5637

# %%
df[(df.iyear>2010)&(df.ishostkid==1)].groupby('iyear').eventid.count().plot()
